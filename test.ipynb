# %%
import pandas as pd

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from langfuse import Langfuse
from dotenv import load_dotenv

load_dotenv()

langfuse = Langfuse()  # Auto-reads LANGFUSE_* env vars

# # def download_all_traces_to_csv(
# #     output_file: str = "my_langfuse_traces_nov2025.csv",
# #     days: int = 180,
# #     limit_per_page: int = 100,
# # ):
# output_file: str = "my_langfuse_traces_nov2025.csv",
# days= 1
# limit_per_page: int = 100,
# all_traces = []
# page = 1
# from_dt = datetime.utcnow() - timedelta(days=days)

# print(f"Downloading all traces from the last {days} days (since {from_dt.isoformat()}Z)...")

# while True:
#     print(f"Fetching page {page} (limit={limit_per_page})...")

#     response = langfuse.api.trace.list(
#         page=page,
#         limit=limit_per_page,
#         from_timestamp=from_dt,
#         order_by="timestamp.DESC",
#         # THIS IS THE KEY: explicitly ask for token usage & cost
#         fields="core,io,metrics,scores",
#         # core = id, timestamp, name, etc.
#         # io    = input/output
#         # metrics = "latency, totalCost, inputTokens, outputTokens, etc",
#         # scores = optional
#     )

#     if not response.data or len(response.data) == 0:
#         print("No more traces. Done!")
#         break

#     print(f"  → Got {len(response.data)} traces (total so far: {len(all_traces) + len(response.data)})")
#     trace = response.data
#     # for trace in response.data:
#     #     # Now these fields exist because we requested "metrics"
#     #     all_traces.append({
#     #         "trace_id": trace.id,
#     #         "timestamp": trace.timestamp.isoformat() if trace.timestamp else None,
#     #         "name": trace.name or "",
#     #         "user_id": trace.user_id or "",
#     #         "session_id": trace.session_id or "",
#     #         "input": trace.input,
#     #         "output": trace.output,
#     #         "model": getattr(trace, "model", None),  
#     #         "input_tokens": getattr(trace, "input_tokens", None),
#     #         "output_tokens": getattr(trace, "output_tokens", None),
#     #         "total_tokens": getattr(trace, "total_tokens", None),
#     #         "input_cost_usd": getattr(trace, "input_cost", None),
#     #         "output_cost_usd": getattr(trace, "output_cost", None),
#     #         "total_cost_usd": getattr(trace, "total_cost", None),
#     #         "latency_seconds": getattr(trace, "latency", None),
#     #         "metadata": str(trace.metadata) if trace.metadata else "",
#     #         "tags": ", ".join(trace.tags) if hasattr(trace, "tags") and trace.tags else "",
#     #         "release": trace.release or "",
#     #         "version": trace.version or "",
#     #     })

#     # page += 1

# # Save
# if all_traces:
# df = pd.DataFrame(trace)
#     print(df)
#     # df.to_csv(output_file, index=False)
#     total_cost = df["total_cost_usd"].sum()
#     print(f"\nSUCCESS! Exported {len(df):,} traces → {output_file}")
#     print(f"Total LLM cost in period: ${total_cost:,.6f}")
# else:
#     print("No traces found.")


# RUN
# if __name__ == "__main__":
#     print(download_all_traces_to_csv(days=180, limit_per_page=100))

# %%
x = langfuse.api.observations.get_many()
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 x = langfuse.api.observations.get_many()
#
# File c:\Users\RohitKaushal\OneDrive - Xebia\Desktop\Code_execution_mcp\venv\lib\site-packages\langfuse\api\resources\observations\client.py:299, in ObservationsClient.get_many(self, page, limit, name, user_id, type, trace_id, level, parent_observation_id, environment, from_start_time, to_start_time, version, filter, request_options)
#     297     raise Error(pydantic_v1.parse_obj_as(typing.Any, _response.json()))  # type: ignore
#     298 if _response.status_code == 401:
# --> 299     raise UnauthorizedError(
#     300         pydantic_v1.parse_obj_as(typing.Any, _response.json())
#     301     )  # type: ignore
#     302 if _response.status_code == 403:
#     303     raise AccessDeniedError(
#     304         pydantic_v1.parse_obj_as(typing.Any, _response.json())
#     305     )  # type: ignore
#
# UnauthorizedError: status_code: 401, body: {'message': "Invalid credentials. Confirm that you've configured the correct host."}

# %%
obs = langfuse.api.observations.get_many()

# %%
for o in obs.data:
    print(o)
# Out:
# id='8ff8a47e86cfd727' trace_id='2972003d22ac40b56fbde28d84599945' type='GENERATION' name='OpenAI-generation' start_time=datetime.datetime(2025, 11, 18, 10, 37, 16, 654000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 37, 19, 662000, tzinfo=datetime.timezone.utc) completion_start_time=None model='gpt-4o-mini-2024-07-18' model_parameters={'temperature': 0, 'max_tokens': 'Infinity', 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0} input=[{'role': 'system', 'content': 'You are an expert fact-checker. Score factual correctness from 0.0 to 1.0.\n\nQuestion: {\'model\': \'azure/gpt-4o-mini\', \'config\': {\'system_instruction\': \'\\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\\n\\n**Core Directives:**\\n\\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\\n* **No Redundancy:** Never ask agents to confirm actions or information.\\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\\n* **Recency Priority:** Base decisions on the most recent user message.\\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\\n\\n**Efficiency Rule:** \\n> **Dependency Resolution Loop:**  \\n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\\n        **Agent Roster:**\\n\\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\\n        * Currently Active Seller Agent: `Get Department Manager`\\n                \\n\\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".\', \'tools\': [{\'function_declarations\': [{\'description\': \'Sends a task to remote seller agent.\\n\\nThis will send a message to the remote agent named agent_name.\\n\\nArgs:\\n    agent_name: The name of the agent to send the task to.\\n    task: The comprehensive conversation context summary\\n        and goal to be achieved regarding user inquiry and purchase request.\\n    tool_context: The tool context this method runs in.\\n\\nYields:\\n    A dictionary of JSON data.\\n\', \'name\': \'send_message\', \'parameters\': {\'properties\': {\'agent_name\': {\'type\': \'STRING\'}, \'task\': {\'type\': \'STRING\'}}, \'required\': [\'agent_name\', \'task\'], \'type\': \'OBJECT\'}, \'response\': {}}]}], \'labels\': {\'adk_agent_name\': \'Routing_agent\'}}, \'contents\': [{\'parts\': [{\'text\': \'give me the manager name for the department Marketing \'}], \'role\': \'user\'}, {\'parts\': [{\'function_call\ ...
# id='f3151f1b51cec542' trace_id='077be7a953d802a8ebc08a49d9ac6fa0' type='GENERATION' name='OpenAI-generation' start_time=datetime.datetime(2025, 11, 18, 10, 35, 36, 926000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 35, 41, 325000, tzinfo=datetime.timezone.utc) completion_start_time=None model='gpt-4o-mini-2024-07-18' model_parameters={'temperature': 0, 'max_tokens': 'Infinity', 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0} input=[{'role': 'system', 'content': 'You are an expert fact-checker.\nScore the answer for factual correctness and completeness from 0.0 to 1.0.\n\nQuestion:\nNone\n\nAnswer:\n{\'content\': {\'parts\': [{\'text\': \'Here is the requested information for the Marketing department:\\n\\n```json\\n{\\n    "department_number": "d001",\\n    "manager_name": "Alejandro Brender"\\n}\\n```\'}], \'role\': \'model\'}, \'partial\': False, \'usage_metadata\': {\'candidates_token_count\': 38, \'prompt_token_count\': 2325, \'total_token_count\': 2363}}\n\nRules:\n- 1.0 = 100% factually correct and complete\n- 0.8–0.9 = minor issues\n- <0.7 = major errors or hallucinations\n\nRespond ONLY with JSON:\n{"score": 0.94, "explanation": "short reason"}'}] version=None metadata={'response_format': {'type': 'json_object'}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output={'role': 'assistant', 'content': '{"score": 0.94, "explanation": "The information provided appears to be accurate and relevant to the Marketing department, but without context or verification of the department number and manager\'s name, there is a slight uncertainty."}'} usage=Usage(input=200, output=49, total=249, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={'input': 200, 'output': 49, 'total': 249, 'input_audio_tokens': 0, 'input_cached_tokens': 0, 'output_accepted_prediction_tokens': 0, 'output_audio_tokens': 0, 'output_reasoning_tokens': 0, 'output_rejected_prediction_tokens': 0} cost_details={'input': 3e-05, 'output': 2.94e-05, 'input_cached_tokens': 0.0, 'total': 5.94e-05} environment='default' prompt_name=None prompt_version=None model_id='clyrjpbe20000t0mzcbwc42rg' input_price=1.5e-07 output_price=6e-07 total_price=None calculated_input_cost=3e-05 calculated_output_cost=2.94e-05 calculated_total_cost=5.94e-05 latency=4399.0 time_to_first_token=None createdAt='2025-11-18T10:35:44.391Z' updatedAt='2025-11-18T10:35:44.392Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=249 unit='TOKENS' completionTokens=49 promptTokens=200
# id='107715e0c3f9ab12' trace_id='9933803dbf480de21de2e05f9c72dfe2' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 23, 29, 616000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 23, 29, 618000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=2.0 time_to_first_token=None createdAt='2025-11-18T10:23:32.817Z' updatedAt='2025-11-18T10:23:32.817Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='c0c1c3400ac60105' trace_id='4005f1d1f9c2c41512c1a870f23d1bdf' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 23, 21, 92000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 23, 21, 94000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=2.0 time_to_first_token=None createdAt='2025-11-18T10:23:22.465Z' updatedAt='2025-11-18T10:23:22.465Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='ffda23a44b064191' trace_id='dbffdb85dc67b6bfce9c73f77f040450' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 22, 7, 39000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 22, 7, 41000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=2.0 time_to_first_token=None createdAt='2025-11-18T10:22:12.022Z' updatedAt='2025-11-18T10:22:12.022Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='dc69c63733b99d21' trace_id='68563bdee08ed0d85210028a8c69fd18' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 22, 7, 37000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 22, 7, 37000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T10:22:12.022Z' updatedAt='2025-11-18T10:22:12.022Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='28bb7b556cb9d6ef' trace_id='177c9571fc2aaf5d55ce827730e6865f' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T10:21:57.916Z' updatedAt='2025-11-18T10:21:57.916Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='cb9070efe197410a' trace_id='580c9a4b2d6f94e1e7889f73c5572b8f' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 21, 54, 228000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=1.0 time_to_first_token=None createdAt='2025-11-18T10:21:57.916Z' updatedAt='2025-11-18T10:21:57.916Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='bd1554c8fbb8f77e' trace_id='1468b555aec24942d44b17050ed7f7e6' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 19, 48, 910000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 19, 48, 910000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T10:19:51.918Z' updatedAt='2025-11-18T10:19:51.919Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='ad6e7369a0241b56' trace_id='e01ba628fffc9a939d51aa08739f5638' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 19, 48, 909000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 19, 48, 909000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T10:19:51.918Z' updatedAt='2025-11-18T10:19:51.919Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='77009b5a49ab645c' trace_id='18e9097a198981a6426e72a7b8402fd4' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 17, 51, 454000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 17, 51, 455000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=1.0 time_to_first_token=None createdAt='2025-11-18T10:17:55.701Z' updatedAt='2025-11-18T10:17:55.701Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='f9bbdb7114616840' trace_id='b357201eb162b08179dabc3b2da76ae4' type='SPAN' name='my-operation' start_time=datetime.datetime(2025, 11, 18, 10, 17, 51, 447000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 10, 17, 51, 451000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.38.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'langfuse-sdk', 'version': '3.10.0', 'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id=None prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=4.0 time_to_first_token=None createdAt='2025-11-18T10:17:55.701Z' updatedAt='2025-11-18T10:17:55.701Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='90ac86de272e159e' trace_id='8b10f6c08185525b60ce1db01d22a156' type='GENERATION' name='call_llm' start_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 122000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 36, 364000, tzinfo=datetime.timezone.utc) completion_start_time=None model='azure/gpt-4o-mini' model_parameters={} input={'model': 'azure/gpt-4o-mini', 'config': {'system_instruction': '\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\n\n**Core Directives:**\n\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\n* **No Redundancy:** Never ask agents to confirm actions or information.\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\n* **Recency Priority:** Base decisions on the most recent user message.\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\n\n**Efficiency Rule:** \n> **Dependency Resolution Loop:**  \n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\n        **Agent Roster:**\n\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\n        * Currently Active Seller Agent: `Get Department Manager`\n                \n\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".', 'tools': [{'function_declarations': [{'description': 'Sends a task to remote seller agent.\n\nThis will send a message to the remote agent named agent_name.\n\nArgs:\n    agent_name: The name of the agent to send the task to.\n    task: The comprehensive conversation context summary\n        and goal to be achieved regarding user inquiry and purchase request.\n    tool_context: The tool context this method runs in.\n\nYields:\n    A dictionary of JSON data.\n', 'name': 'send_message', 'parameters': {'properties': {'agent_name': {'type': 'STRING'}, 'task': {'type': 'STRING'}}, 'required': ['agent_name', 'task'], 'type': 'OBJECT'}, 'response': {}}]}], 'labels': {'adk_agent_name': 'Routing_agent'}}, 'contents': [{'parts': [{'text': 'Give me the manager name for the department Marketing'}], 'role': 'user'}, {'parts': [{'function_call': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw', 'args': {'agent_name': 'Get Dept Number', 'task': "Need the department number for the department named Marketing in order to get the department manager's name."}, 'name': 'send_message'}}], 'role': 'model'}, {'parts': [{'function_response': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw', 'name': 'send_message', ' ...
# id='adc065c85855a38a' trace_id='8b10f6c08185525b60ce1db01d22a156' type='SPAN' name='a2a.client.transports.jsonrpc.JsonRpcTransport._send_request' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 111000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='9ec6fa4a81f47d35' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=14259.0 time_to_first_token=None createdAt='2025-11-18T09:18:36.184Z' updatedAt='2025-11-18T09:18:36.184Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='4091e9b88a017f16' trace_id='8b10f6c08185525b60ce1db01d22a156' type='SPAN' name='a2a.client.transports.jsonrpc.JsonRpcTransport._apply_interceptors' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='9ec6fa4a81f47d35' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:25.825Z' updatedAt='2025-11-18T09:18:25.826Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='9ec6fa4a81f47d35' trace_id='8b10f6c08185525b60ce1db01d22a156' type='SPAN' name='a2a.client.transports.jsonrpc.JsonRpcTransport.send_message' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 111000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='cd43de3332e811db' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=14260.0 time_to_first_token=None createdAt='2025-11-18T09:18:36.184Z' updatedAt='2025-11-18T09:18:36.184Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='82085cac7fc7b9ed' trace_id='8b10f6c08185525b60ce1db01d22a156' type='SPAN' name='a2a.client.transports.jsonrpc.JsonRpcTransport._get_http_args' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='9ec6fa4a81f47d35' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:25.825Z' updatedAt='2025-11-18T09:18:25.826Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='cd43de3332e811db' trace_id='8b10f6c08185525b60ce1db01d22a156' type='SPAN' name='send_message' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 849000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 113000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input={'args': [], 'kwargs': {'agent_name': 'Get Department Manager', 'task': "Need the manager's name for the department with number d001, which is the Marketing department.", 'tool_context': {'_invocation_context': {'artifact_service': None, 'session_service': {}, 'memory_service': None, 'credential_service': None, 'context_cache_config': None, 'invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456', 'branch': None, 'agent': {'name': 'Routing_agent', 'description': 'This Routing agent orchestrates the decomposition of the user asking for department or manager information.', 'parent_agent': None, 'sub_agents': [], 'before_agent_callback': None, 'after_agent_callback': None}, 'user_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'Give me the manager name for the department Marketing', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'user'}, 'session': {'id': 'default_session', 'app_name': 'routing_app', 'user_id': 'default_user', 'state': {'session_id': '18731212-f1a0-4e68-9f92-7ebe75b62e8e', 'session_active': True, 'active_agent': 'Get Dept Number'}, 'events': [{'content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'Give me the manager name for the department Marketing', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'user'}, 'grounding_metadata': None, 'partial': None, 'turn_complete': None, 'finish_reason': None, 'error_code': None, 'error_message': None, 'interrupted': None, 'custom_metadata': None, 'usage_metadata': None, 'live_session_resumption_update': None, 'input_transcription': None, 'output_transcription': None, 'avg_logprobs': None, 'logprobs_result': None, 'cache_metadata': None, 'citation_metadata': None, 'invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456', 'author': 'user', 'actions': {'skip_summarization': None, 'state_delta': {}, 'artifact_delta': {}, 'transfer_to_agent': None, 'escalate': None, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}, 'compaction': None, 'end_of_agent': None, 'agent_state': None, 'rewind_before_invocation_id': None}, 'long_running_tool_ids': None, 'branch': None, 'id': '1bc74721-93fd-4e7e-94f9-69f3deb4344c', 'timestamp': 1763457485.564997}, {'content': {'parts': [{'function_call': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw', 'args': {'agent_name': 'Get Dept Number', 'task': "Need the department number for the department named Marketing in order to get the department manager's name."}, 'name': 'send_message'}, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': None, 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}, 'grounding_metadata': None, 'partial': False, 'turn_complete': None, 'finish_reason': None, 'error_code': None, 'error_message': None, 'interrupted': None, 'custom_metadata': None, 'usage_metadata': {'cache_tokens_details': None, 'cached_content_token_count': None, 'candidates_token_count': 40, 'candidates_tokens_details': None, 'prompt_token_count': 601, 'prompt_tokens_details': None, 'thoughts_token_count': None, 'tool_use_prompt_token_count': None, 'tool_use_prompt_tokens_details': None, 'total_token_count': 641, 'traffic_type': None}, 'live_session_resumption_update': None, 'input_transcription': None, 'output_transcription': None, 'avg_logprobs': None, 'logprobs_result': None, 'cache_metadata': ...
# id='c6a35dd7a2d1e85c' trace_id='8b10f6c08185525b60ce1db01d22a156' type='TOOL' name='execute_tool send_message' start_time=datetime.datetime(2025, 11, 18, 9, 18, 20, 849000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 114000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters={} input={'agent_name': 'Get Department Manager', 'task': "Need the manager's name for the department with number d001, which is the Marketing department."} version=None metadata={'attributes': {'gen_ai.operation.name': 'execute_tool', 'gen_ai.tool.description': 'Sends a task to remote seller agent.\n\nThis will send a message to the remote agent named agent_name.\n\nArgs:\n    agent_name: The name of the agent to send the task to.\n    task: The comprehensive conversation context summary\n        and goal to be achieved regarding user inquiry and purchase request.\n    tool_context: The tool context this method runs in.\n\nYields:\n    A dictionary of JSON data.', 'gen_ai.tool.name': 'send_message', 'gen_ai.tool.type': 'FunctionTool', 'gen_ai.tool.call.id': 'call_caUyPqPmnbBdC1rQcqo4kTtB', 'gcp.vertex.agent.event_id': '0d14eb38-506e-4829-b2c6-40629f641366'}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'gcp.vertex.agent', 'version': '1.17.0', 'attributes': {}}} output={'result': '<not serializable>'} usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='5596a2b08c607f23' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=14265.0 time_to_first_token=None createdAt='2025-11-18T09:18:36.184Z' updatedAt='2025-11-18T09:18:36.184Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='5596a2b08c607f23' trace_id='8b10f6c08185525b60ce1db01d22a156' type='GENERATION' name='call_llm' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 56000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 35, 121000, tzinfo=datetime.timezone.utc) completion_start_time=None model='azure/gpt-4o-mini' model_parameters={} input={'model': 'azure/gpt-4o-mini', 'config': {'system_instruction': '\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\n\n**Core Directives:**\n\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\n* **No Redundancy:** Never ask agents to confirm actions or information.\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\n* **Recency Priority:** Base decisions on the most recent user message.\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\n\n**Efficiency Rule:** \n> **Dependency Resolution Loop:**  \n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\n        **Agent Roster:**\n\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\n        * Currently Active Seller Agent: `Get Dept Number`\n                \n\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".', 'tools': [{'function_declarations': [{'description': 'Sends a task to remote seller agent.\n\nThis will send a message to the remote agent named agent_name.\n\nArgs:\n    agent_name: The name of the agent to send the task to.\n    task: The comprehensive conversation context summary\n        and goal to be achieved regarding user inquiry and purchase request.\n    tool_context: The tool context this method runs in.\n\nYields:\n    A dictionary of JSON data.\n', 'name': 'send_message', 'parameters': {'properties': {'agent_name': {'type': 'STRING'}, 'task': {'type': 'STRING'}}, 'required': ['agent_name', 'task'], 'type': 'OBJECT'}, 'response': {}}]}], 'labels': {'adk_agent_name': 'Routing_agent'}}, 'contents': [{'parts': [{'text': 'Give me the manager name for the department Marketing'}], 'role': 'user'}, {'parts': [{'function_call': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw', 'args': {'agent_name': 'Get Dept Number', 'task': "Need the department number for the department named Marketing in order to get the department manager's name."}, 'name': 'send_message'}}], 'role': 'model'}, {'parts': [{'function_response': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw', 'name': 'send_message', 'response ...
# id='62d7ecadff4b3ec6' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.request_handlers.default_request_handler.DefaultRequestHandler._send_push_notification_if_needed' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 41000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 41000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:23.656Z' updatedAt='2025-11-18T09:18:23.657Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='6fc0d12b9603cf3e' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.request_handlers.default_request_handler.DefaultRequestHandler._validate_task_id_match' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 41000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 41000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:23.656Z' updatedAt='2025-11-18T09:18:23.657Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='2354575d0af2c447' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_consumer.EventConsumer.agent_task_callback' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 40000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 40000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:23.656Z' updatedAt='2025-11-18T09:18:23.657Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='e17b99b52c484a4f' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.close' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 40000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 40000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='e202b16582dd9d4c' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:23.656Z' updatedAt='2025-11-18T09:18:23.657Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='e202b16582dd9d4c' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.in_memory_queue_manager.InMemoryQueueManager.close' start_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 40000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 19, 41000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='230fb4d8d95aa019' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=1.0 time_to_first_token=None createdAt='2025-11-18T09:18:23.656Z' updatedAt='2025-11-18T09:18:23.657Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# ...
# id='962df2804541df73' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 536000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=515.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='d9cde16c3d7427cc' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.task_done' start_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.311Z' updatedAt='2025-11-18T09:18:18.312Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='1dce8543576522e3' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.enqueue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 20000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 20000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='8de355e8ec506ff6' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=0.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='190f1928854d1fcc' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 15, 833000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=188.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='9675dd3607add20d' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 15, 319000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 15, 832000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=513.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='61edf1a83dc51e4c' trace_id='bff713e0aaf32710bd3bae79a2143637' type='TOOL' name='execute_tool Get_Department_Number' start_time=datetime.datetime(2025, 11, 18, 9, 18, 15, 10000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 16, 18000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters={} input={'input_dict': '{"department_name": "Marketing"}'} version=None metadata={'attributes': {'gen_ai.operation.name': 'execute_tool', 'gen_ai.tool.description': 'Fetches the department number by department name (case insensitive).\n\n    Args:\n        input_dict: A dictionary with the following keys:\n            - department_name (str): The name of the department to search for.\n\n    Returns:\n        List[Dict[str, Any]]: A list of dictionaries containing:\n            - dept_no (str): The department number associated with the department name.\n    ', 'gen_ai.tool.name': 'Get_Department_Number', 'gen_ai.tool.type': 'MCPTool', 'gen_ai.tool.call.id': 'call_f58iL5BxcHPN7ArgA8STRBnj', 'gcp.vertex.agent.event_id': 'a3e197a9-d854-4c2c-a50b-c520157c92a8'}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'gcp.vertex.agent', 'version': '1.17.0', 'attributes': {}}} output={'content': [{'type': 'text', 'text': '{\n  "dept_no": "d001"\n}'}], 'structuredContent': {'result': [{'dept_no': 'd001'}]}, 'isError': False} usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='8de355e8ec506ff6' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=1008.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.311Z' updatedAt='2025-11-18T09:18:18.312Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='d7b76347737aee84' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 14, 808000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 15, 319000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=511.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='54d03b71de606638' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 14, 290000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 14, 807000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=517.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0
# id='4f0f44e9bacc6c26' trace_id='bff713e0aaf32710bd3bae79a2143637' type='SPAN' name='a2a.server.events.event_queue.EventQueue.dequeue_event' start_time=datetime.datetime(2025, 11, 18, 9, 18, 13, 775000, tzinfo=datetime.timezone.utc) end_time=datetime.datetime(2025, 11, 18, 9, 18, 14, 290000, tzinfo=datetime.timezone.utc) completion_start_time=None model=None model_parameters=None input=None version=None metadata={'attributes': {}, 'resourceAttributes': {'telemetry.sdk.language': 'python', 'telemetry.sdk.name': 'opentelemetry', 'telemetry.sdk.version': '1.37.0', 'service.name': 'unknown_service'}, 'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}} output=None usage=Usage(input=0, output=0, total=0, unit=<ModelUsageUnit.TOKENS: 'TOKENS'>, input_cost=None, output_cost=None, total_cost=None) level=<ObservationLevel.DEFAULT: 'DEFAULT'> status_message=None parent_observation_id='654f9356417884dd' prompt_id=None usage_details={} cost_details={} environment='default' prompt_name=None prompt_version=None model_id=None input_price=None output_price=None total_price=None calculated_input_cost=None calculated_output_cost=None calculated_total_cost=0.0 latency=515.0 time_to_first_token=None createdAt='2025-11-18T09:18:18.310Z' updatedAt='2025-11-18T09:18:18.311Z' projectId='cmhwzwyvs01fjad07xfmlp94h' totalTokens=0 unit='TOKENS' completionTokens=0 promptTokens=0

# %%
obs.dict()
# Out:
# {'data': [{'id': '8ff8a47e86cfd727',
#    'traceId': '2972003d22ac40b56fbde28d84599945',
#    'type': 'GENERATION',
#    'name': 'OpenAI-generation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 37, 16, 654000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 37, 19, 662000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': 'gpt-4o-mini-2024-07-18',
#    'modelParameters': {'temperature': 0,
#     'max_tokens': 'Infinity',
#     'top_p': 1,
#     'frequency_penalty': 0,
#     'presence_penalty': 0},
#    'input': [{'role': 'system',
#      'content': 'You are an expert fact-checker. Score factual correctness from 0.0 to 1.0.\n\nQuestion: {\'model\': \'azure/gpt-4o-mini\', \'config\': {\'system_instruction\': \'\\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\\n\\n**Core Directives:**\\n\\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\\n* **No Redundancy:** Never ask agents to confirm actions or information.\\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\\n* **Recency Priority:** Base decisions on the most recent user message.\\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\\n\\n**Efficiency Rule:** \\n> **Dependency Resolution Loop:**  \\n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\\n        **Agent Roster:**\\n\\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\\n        * Currently Active Seller Agent: `Get Department Manager`\\n                \\n\\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".\', \'tools\': [{\'function_declarations\': [{\'description\': \'Sends a task to remote seller agent.\\n\\nThis will send a message to the remote agent named agent_name.\\n\\nArgs:\\n    agent_name: The name of the agent to send the task to.\\n    task: The comprehensive conversation context summary\\n        and goal to be achieved regarding user inquiry and purchase request.\\n    tool_context: The tool context this method runs in.\\n\\nYields:\\n    A dictionary of JSON data.\\n\', \'name\': \'send_message\', \'parameters\': {\'properties\': {\'agent_name\': {\'type\': \'STRING\'}, \'task\': {\'type\': \'STRING\'}}, \'required\': [\'agent_name\', \'task\'], \'type\': \'OBJECT\'}, \'response\': {}}]}], \'labels\': {\'adk_agent_name\': \'Routing_agent\'}}, \'contents\': [{\'parts\': [{\'text\': \'give me the manager name for the department Marketing \'}], \'role\': \'user\'}, {\'parts\': [{\'function_call\': {\'id\': \'call_864soeZGp5hioF6g2A9vB2KD\', \'args\': {\'agent_name\': \'Get Dept Number\', \'task\': "User is requesting the manager\'s name for the Marketing department. First, find the department number for Marketing."}, \'name\': \'send_message\'}}], \'role\': \'model\'}, {\'parts\': [{\'function_response\': {\'id\': \'call_864soeZGp5hioF6g2A9vB2KD\', \'name\': \'send_message\', \'response\': {\'result\': {\'artifacts\': [{\'artifactId\': \'50710bf0-5d5d-4ece-b711-5c71c85f637f\', \ ...
#    'version': None,
#    'metadata': {'response_format': {'type': 'json_object'},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': {'role': 'assistant',
#     'content': '{"score": 0.94, "explanation": "The response accurately provides the department number and manager\'s name for the Marketing department as requested, but the context of the conversation suggests that the retrieval process involved multiple steps, which could lead to minor inaccuracies in the overall process."}'},
#    'usage': {'input': 2675,
#     'output': 59,
#     'total': 2734,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {'input': 2675,
#     'output': 59,
#     'total': 2734,
#     'input_audio_tokens': 0,
#     'input_cached_tokens': 0,
#     'output_accepted_prediction_tokens': 0,
#     'output_audio_tokens': 0,
#     'output_reasoning_tokens': 0,
#     'output_rejected_prediction_tokens': 0},
#    'costDetails': {'input': 0.00040125,
#     'output': 3.54e-05,
#     'input_cached_tokens': 0.0,
#     'total': 0.00043665},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': 'clyrjpbe20000t0mzcbwc42rg',
#    'inputPrice': 1.5e-07,
#    'outputPrice': 6e-07,
#    'totalPrice': None,
#    'calculatedInputCost': 0.00040125,
#    'calculatedOutputCost': 3.54e-05,
#    'calculatedTotalCost': 0.00043665,
#    'latency': 3008.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:37:20.058Z',
#    'updatedAt': '2025-11-18T10:37:20.058Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 2734,
#    'unit': 'TOKENS',
#    'completionTokens': 59,
#    'promptTokens': 2675},
#   {'id': 'f3151f1b51cec542',
#    'traceId': '077be7a953d802a8ebc08a49d9ac6fa0',
#    'type': 'GENERATION',
#    'name': 'OpenAI-generation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 35, 36, 926000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 35, 41, 325000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': 'gpt-4o-mini-2024-07-18',
#    'modelParameters': {'temperature': 0,
#     'max_tokens': 'Infinity',
#     'top_p': 1,
#     'frequency_penalty': 0,
#     'presence_penalty': 0},
#    'input': [{'role': 'system',
#      'content': 'You are an expert fact-checker.\nScore the answer for factual correctness and completeness from 0.0 to 1.0.\n\nQuestion:\nNone\n\nAnswer:\n{\'content\': {\'parts\': [{\'text\': \'Here is the requested information for the Marketing department:\\n\\n```json\\n{\\n    "department_number": "d001",\\n    "manager_name": "Alejandro Brender"\\n}\\n```\'}], \'role\': \'model\'}, \'partial\': False, \'usage_metadata\': {\'candidates_token_count\': 38, \'prompt_token_count\': 2325, \'total_token_count\': 2363}}\n\nRules:\n- 1.0 = 100% factually correct and complete\n- 0.8–0.9 = minor issues\n- <0.7 = major errors or hallucinations\n\nRespond ONLY with JSON:\n{"score": 0.94, "explanation": "short reason"}'}],
#    'version': None,
#    'metadata': {'response_format': {'type': 'json_object'},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': {'role': 'assistant',
#     'content': '{"score": 0.94, "explanation": "The information provided appears to be accurate and relevant to the Marketing department, but without context or verification of the department number and manager\'s name, there is a slight uncertainty."}'},
#    'usage': {'input': 200,
#     'output': 49,
#     'total': 249,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {'input': 200,
#     'output': 49,
#     'total': 249,
#     'input_audio_tokens': 0,
#     'input_cached_tokens': 0,
#     'output_accepted_prediction_tokens': 0,
#     'output_audio_tokens': 0,
#     'output_reasoning_tokens': 0,
#     'output_rejected_prediction_tokens': 0},
#    'costDetails': {'input': 3e-05,
#     'output': 2.94e-05,
#     'input_cached_tokens': 0.0,
#     'total': 5.94e-05},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': 'clyrjpbe20000t0mzcbwc42rg',
#    'inputPrice': 1.5e-07,
#    'outputPrice': 6e-07,
#    'totalPrice': None,
#    'calculatedInputCost': 3e-05,
#    'calculatedOutputCost': 2.94e-05,
#    'calculatedTotalCost': 5.94e-05,
#    'latency': 4399.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:35:44.391Z',
#    'updatedAt': '2025-11-18T10:35:44.392Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 249,
#    'unit': 'TOKENS',
#    'completionTokens': 49,
#    'promptTokens': 200},
#   {'id': '107715e0c3f9ab12',
#    'traceId': '9933803dbf480de21de2e05f9c72dfe2',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 23, 29, 616000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 23, 29, 618000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 2.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:23:32.817Z',
#    'updatedAt': '2025-11-18T10:23:32.817Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'c0c1c3400ac60105',
#    'traceId': '4005f1d1f9c2c41512c1a870f23d1bdf',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 23, 21, 92000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 23, 21, 94000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 2.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:23:22.465Z',
#    'updatedAt': '2025-11-18T10:23:22.465Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'ffda23a44b064191',
#    'traceId': 'dbffdb85dc67b6bfce9c73f77f040450',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 22, 7, 39000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 22, 7, 41000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 2.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:22:12.022Z',
#    'updatedAt': '2025-11-18T10:22:12.022Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'dc69c63733b99d21',
#    'traceId': '68563bdee08ed0d85210028a8c69fd18',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 22, 7, 37000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 22, 7, 37000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:22:12.022Z',
#    'updatedAt': '2025-11-18T10:22:12.022Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '28bb7b556cb9d6ef',
#    'traceId': '177c9571fc2aaf5d55ce827730e6865f',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:21:57.916Z',
#    'updatedAt': '2025-11-18T10:21:57.916Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'cb9070efe197410a',
#    'traceId': '580c9a4b2d6f94e1e7889f73c5572b8f',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 21, 54, 228000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 21, 54, 229000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 1.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:21:57.916Z',
#    'updatedAt': '2025-11-18T10:21:57.916Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'bd1554c8fbb8f77e',
#    'traceId': '1468b555aec24942d44b17050ed7f7e6',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 19, 48, 910000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 19, 48, 910000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:19:51.918Z',
#    'updatedAt': '2025-11-18T10:19:51.919Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'ad6e7369a0241b56',
#    'traceId': 'e01ba628fffc9a939d51aa08739f5638',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 19, 48, 909000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 19, 48, 909000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:19:51.918Z',
#    'updatedAt': '2025-11-18T10:19:51.919Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '77009b5a49ab645c',
#    'traceId': '18e9097a198981a6426e72a7b8402fd4',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 17, 51, 454000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 17, 51, 455000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 1.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:17:55.701Z',
#    'updatedAt': '2025-11-18T10:17:55.701Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'f9bbdb7114616840',
#    'traceId': 'b357201eb162b08179dabc3b2da76ae4',
#    'type': 'SPAN',
#    'name': 'my-operation',
#    'startTime': datetime.datetime(2025, 11, 18, 10, 17, 51, 447000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 10, 17, 51, 451000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.38.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'langfuse-sdk',
#      'version': '3.10.0',
#      'attributes': {'public_key': 'pk-lf-08d46561-1857-47c0-9c24-5ba0354abc4e'}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': None,
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 4.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T10:17:55.701Z',
#    'updatedAt': '2025-11-18T10:17:55.701Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '90ac86de272e159e',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'GENERATION',
#    'name': 'call_llm',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 35, 122000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 36, 364000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': 'azure/gpt-4o-mini',
#    'modelParameters': {},
#    'input': {'model': 'azure/gpt-4o-mini',
#     'config': {'system_instruction': '\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\n\n**Core Directives:**\n\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\n* **No Redundancy:** Never ask agents to confirm actions or information.\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\n* **Recency Priority:** Base decisions on the most recent user message.\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\n\n**Efficiency Rule:** \n> **Dependency Resolution Loop:**  \n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\n        **Agent Roster:**\n\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\n        * Currently Active Seller Agent: `Get Department Manager`\n                \n\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".',
#      'tools': [{'function_declarations': [{'description': 'Sends a task to remote seller agent.\n\nThis will send a message to the remote agent named agent_name.\n\nArgs:\n    agent_name: The name of the agent to send the task to.\n    task: The comprehensive conversation context summary\n        and goal to be achieved regarding user inquiry and purchase request.\n    tool_context: The tool context this method runs in.\n\nYields:\n    A dictionary of JSON data.\n',
#          'name': 'send_message',
#          'parameters': {'properties': {'agent_name': {'type': 'STRING'},
#            'task': {'type': 'STRING'}},
#           'required': ['agent_name', 'task'],
#           'type': 'OBJECT'},
#          'response': {}}]}],
#      'labels': {'adk_agent_name': 'Routing_agent'}},
#     'contents': [{'parts': [{'text': 'Give me the manager name for the department Marketing'}],
#       'role': 'user'},
#      {'parts': [{'function_call': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw',
#          'args': {'agent_name': 'Get Dept Number',
#           'task': "Need the department number for the department named Marketing in order to get the department manager's name."},
#          'name': 'send_message'}}],
#       'role': 'model'},
#      {'parts': [{'function_response': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw',
#          'name': 'send_message',
#          'response': {'result': {'artifacts': [{'artifactId': '610b52b7-21bd-4ce1-a469-1a26f9754df5',
#              'parts': [{'kind': 'text',
#                'text': 'The department number for the department named "Marketing" is retrieved successfully. Here are the details:\n\n```json\n{\n    "department_number": "d001",\n    "department_name": "Marketing"\n}\n```'}]}],
#            'contextId': '1768842e-8d7a-4628-b1d3-d9265d446f92',
#            'history': [{'contextId': '1768842e-8d7a-4628-b1d3-d9265d446f92',
#              'kind': 'message',
#              'messageId': '6738e0ab-ef77-4641-9dd7-faab7aba765c',
#              'parts': [{'kind': 'text',
#                'text': "Need the department number for the department named Marketing in order to get the department manager's name."}],
#              'role': 'user',
#              'taskId': '277569e4-e1df-435f-b3a8-86e71c9b7403'},
#             {'contextId': '1768842e-8d7a-4628-b1d3-d9265d446f92',
#              'kind': 'message',
#              'messageId': '2130cd10-8dbd-4946-a5bc-cf395600779d',
#              'parts': [],
#              'role': 'agent',
#              'taskId': '277569e4-e1df-435f-b3a8-86e71c9b7403'}],
#            'id': '277569e4-e1df-435f-b3a8-86e71c9b7403',
#            'kind': 'task',
#            'status': {'state': 'completed',
#             'timestamp': '2025-11-18T09:18:19.021899+00:00'}}}}}],
#       'role': 'user'},
#      {'parts': [{'function_call': {'id': 'call_caUyPqPmnbBdC1rQcqo4kTtB',
#          'args': {'agent_name': 'Get Department Manager',
#           'task': "Need the manager's name for the department with number d001, which is the Marketing department."},
#          'name': 'send_message'}}],
#       'role': 'model'},
#      {'parts': [{'function_response': {'id': 'call_caUyPqPmnbBdC1rQcqo4kTtB',
#          'name': 'send_message',
#          'response': {'result': {'artifacts': [{'artifactId': '31cd0f54-2ac8-4be5-81b3-6f2044335f5b',
#              'parts': [{'kind': 'text',
#                'text': 'Here is the information for the department number d001 (Marketing):\n\n```json\n{\n    "department_number": "d001",\n    "manager_name": "Alejandro Brender"\n}\n```'}]}],
#            'contextId': 'cdd6bbff-8561-415b-b0e5-2db236d85656',
#            'history': [{'contextId': 'cdd6bbff-8561-415b-b0e5-2db236d85656',
#              'kind': 'message',
#              'messageId': 'c97c2ad1-9223-4cb1-8667-9a37336fb5ae',
#              'parts': [{'kind': 'text',
#                'text': "Need the manager's name for the department with number d001, which is the Marketing department."}],
#              'role': 'user',
#              'taskId': 'cc5df0c2-3435-42cd-99c1-192af9badd15'},
#             {'contextId': 'cdd6bbff-8561-415b-b0e5-2db236d85656',
#              'kind': 'message',
#              'messageId': '2906e966-f0e5-43bc-be14-25b340d9bdfc',
#              'parts': [],
#              'role': 'agent',
#              'taskId': 'cc5df0c2-3435-42cd-99c1-192af9badd15'}],
#            'id': 'cc5df0c2-3435-42cd-99c1-192af9badd15',
#            'kind': 'task',
#            'status': {'state': 'completed',
#             'timestamp': '2025-11-18T09:18:35.106343+00:00'}}}}}],
#       'role': 'user'}]},
#    'version': None,
#    'metadata': {'attributes': {'gen_ai.system': 'gcp.vertex.agent',
#      'gen_ai.request.model': 'azure/gpt-4o-mini',
#      'gcp.vertex.agent.invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456',
#      'gcp.vertex.agent.session_id': 'default_session',
#      'gcp.vertex.agent.event_id': 'b0adcd64-f63d-4c61-9cfb-841ab72dd664',
#      'gen_ai.usage.input_tokens': '1632',
#      'gen_ai.usage.output_tokens': '20'},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'gcp.vertex.agent',
#      'version': '1.17.0',
#      'attributes': {}}},
#    'output': {'content': {'parts': [{'text': 'The manager name for the Marketing department (department number d001) is Alejandro Brender.'}],
#      'role': 'model'},
#     'partial': False,
#     'usage_metadata': {'candidates_token_count': 20,
#      'prompt_token_count': 1632,
#      'total_token_count': 1652}},
#    'usage': {'input': 1632,
#     'output': 20,
#     'total': 1652,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '2859ace254737f36',
#    'promptId': None,
#    'usageDetails': {'input': 1632, 'output': 20, 'total': 1652},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 1242.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:41.565Z',
#    'updatedAt': '2025-11-18T09:18:41.565Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 1652,
#    'unit': 'TOKENS',
#    'completionTokens': 20,
#    'promptTokens': 1632},
#   {'id': 'adc065c85855a38a',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'SPAN',
#    'name': 'a2a.client.transports.jsonrpc.JsonRpcTransport._send_request',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 35, 111000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '9ec6fa4a81f47d35',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 14259.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:36.184Z',
#    'updatedAt': '2025-11-18T09:18:36.184Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '4091e9b88a017f16',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'SPAN',
#    'name': 'a2a.client.transports.jsonrpc.JsonRpcTransport._apply_interceptors',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 852000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '9ec6fa4a81f47d35',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:25.825Z',
#    'updatedAt': '2025-11-18T09:18:25.826Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '9ec6fa4a81f47d35',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'SPAN',
#    'name': 'a2a.client.transports.jsonrpc.JsonRpcTransport.send_message',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 35, 111000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': 'cd43de3332e811db',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 14260.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:36.184Z',
#    'updatedAt': '2025-11-18T09:18:36.184Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '82085cac7fc7b9ed',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'SPAN',
#    'name': 'a2a.client.transports.jsonrpc.JsonRpcTransport._get_http_args',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 851000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '9ec6fa4a81f47d35',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:25.825Z',
#    'updatedAt': '2025-11-18T09:18:25.826Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'cd43de3332e811db',
#    'traceId': '8b10f6c08185525b60ce1db01d22a156',
#    'type': 'SPAN',
#    'name': 'send_message',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 20, 849000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 35, 113000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': {'args': [],
#     'kwargs': {'agent_name': 'Get Department Manager',
#      'task': "Need the manager's name for the department with number d001, which is the Marketing department.",
#      'tool_context': {'_invocation_context': {'artifact_service': None,
#        'session_service': {},
#        'memory_service': None,
#        'credential_service': None,
#        'context_cache_config': None,
#        'invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456',
#        'branch': None,
#        'agent': {'name': 'Routing_agent',
#         'description': 'This Routing agent orchestrates the decomposition of the user asking for department or manager information.',
#         'parent_agent': None,
#         'sub_agents': [],
#         'before_agent_callback': None,
#         'after_agent_callback': None},
#        'user_content': {'parts': [{'function_call': None,
#           'code_execution_result': None,
#           'executable_code': None,
#           'file_data': None,
#           'function_response': None,
#           'inline_data': None,
#           'text': 'Give me the manager name for the department Marketing',
#           'thought': None,
#           'thought_signature': None,
#           'video_metadata': None}],
#         'role': 'user'},
#        'session': {'id': 'default_session',
#         'app_name': 'routing_app',
#         'user_id': 'default_user',
#         'state': {'session_id': '18731212-f1a0-4e68-9f92-7ebe75b62e8e',
#          'session_active': True,
#          'active_agent': 'Get Dept Number'},
#         'events': [{'content': {'parts': [{'function_call': None,
#              'code_execution_result': None,
#              'executable_code': None,
#              'file_data': None,
#              'function_response': None,
#              'inline_data': None,
#              'text': 'Give me the manager name for the department Marketing',
#              'thought': None,
#              'thought_signature': None,
#              'video_metadata': None}],
#            'role': 'user'},
#           'grounding_metadata': None,
#           'partial': None,
#           'turn_complete': None,
#           'finish_reason': None,
#           'error_code': None,
#           'error_message': None,
#           'interrupted': None,
#           'custom_metadata': None,
#           'usage_metadata': None,
#           'live_session_resumption_update': None,
#           'input_transcription': None,
#           'output_transcription': None,
#           'avg_logprobs': None,
#           'logprobs_result': None,
#           'cache_metadata': None,
#           'citation_metadata': None,
#           'invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456',
#           'author': 'user',
#           'actions': {'skip_summarization': None,
#            'state_delta': {},
#            'artifact_delta': {},
#            'transfer_to_agent': None,
#            'escalate': None,
#            'requested_auth_configs': {},
#            'requested_tool_confirmations': {},
#            'compaction': None,
#            'end_of_agent': None,
#            'agent_state': None,
#            'rewind_before_invocation_id': None},
#           'long_running_tool_ids': None,
#           'branch': None,
#           'id': '1bc74721-93fd-4e7e-94f9-69f3deb4344c',
#           'timestamp': 1763457485.564997},
#          {'content': {'parts': [{'function_call': {'id': 'call_WRxAs89PVEqKhj5sEOehR4iw',
#               'args': {'agent_name': 'Get Dept Number',
#                'task': "Need the department number for the department named Marketing in order to get the department manager's name."},
#               'name': 'send_message'},
#              'code_execution_result': None,
#              'executable_code': None,
#              'file_data': None,
#              'function_response': None,
#              'inline_data': None,
#              'text': None,
#              'thought': None,
#              'thought_signature': None,
#              'video_metadata': None}],
#            'role': 'model'},
#           'grounding_metadata': None,
#           'partial': False,
#           'turn_complete': None,
#           'finish_reason': None,
#           'error_code': None,
#           'error_message': None,
#           'interrupted': None,
#           'custom_metadata': None,
#           'usage_metadata': {'cache_tokens_details': None,
#            'cached_content_token_count': None,
#            'candidates_token_count': 40,
#            'candidates_tokens_details': None,
#            'prompt_token_count': 601,
#            'prompt_tokens_details': None,
#            'thoughts_token_count': None,
#            'tool_use_prompt_token_count': None,
#            'tool_use_prompt_tokens_details': None,
#            'total_token_count': 641,
#            'traffic_type': None},
#           'live_session_resumption_update': None,
#           'input_transcription': None,
#           'output_transcription': None,
#           'avg_logprobs': None,
#           'logprobs_result': None,
#           'cache_metadata': None,
#           'citation_metadata': None,
#           'invocation_id': 'e-5d015781-aa95-4c9d-921a-55c62b5a9456',
#           'author': 'Routing_agent',
#           'actions': {'skip_summarization': None,
#            'state_delta': {'session_id': '18731212-f1a0-4e68-9f92-7ebe75b62e8e',
#             'session_active': True},
#            'artifact_delta': {},
#            'transfer_to_agent': None,
#            'escalate': None,
#            'requested_auth_configs': {},
#            'requested_tool_confirmations': {},
#            'compaction': None,
#            'end_of_agent': None,
#            'agent_state': None,
#            'rewind_before_invocation_id': None},
#           'long_running_tool_ids': [],
#           'branch': None,
#           'id': '3c02810f-5297-4cca-9fd1-38afd6837b6f',
#           'timestamp': 1763457485.579287},
#          {'content': {'parts': [{'function_call': None,
#              'code_execution_result': None,
# ...
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 2544.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:23.656Z',
#    'updatedAt': '2025-11-18T09:18:23.657Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 432,
#    'unit': 'TOKENS',
#    'completionTokens': 44,
#    'promptTokens': 388},
#   {'id': '962df2804541df73',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 536000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 515.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'd9cde16c3d7427cc',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.task_done',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.311Z',
#    'updatedAt': '2025-11-18T09:18:18.312Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '1dce8543576522e3',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.enqueue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 20000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 20000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '8de355e8ec506ff6',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 0.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '190f1928854d1fcc',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 15, 833000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 21000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 188.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '9675dd3607add20d',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 15, 319000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 15, 832000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 513.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '61edf1a83dc51e4c',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'TOOL',
#    'name': 'execute_tool Get_Department_Number',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 15, 10000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 16, 18000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': {},
#    'input': {'input_dict': '{"department_name": "Marketing"}'},
#    'version': None,
#    'metadata': {'attributes': {'gen_ai.operation.name': 'execute_tool',
#      'gen_ai.tool.description': 'Fetches the department number by department name (case insensitive).\n\n    Args:\n        input_dict: A dictionary with the following keys:\n            - department_name (str): The name of the department to search for.\n\n    Returns:\n        List[Dict[str, Any]]: A list of dictionaries containing:\n            - dept_no (str): The department number associated with the department name.\n    ',
#      'gen_ai.tool.name': 'Get_Department_Number',
#      'gen_ai.tool.type': 'MCPTool',
#      'gen_ai.tool.call.id': 'call_f58iL5BxcHPN7ArgA8STRBnj',
#      'gcp.vertex.agent.event_id': 'a3e197a9-d854-4c2c-a50b-c520157c92a8'},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'gcp.vertex.agent',
#      'version': '1.17.0',
#      'attributes': {}}},
#    'output': {'content': [{'type': 'text',
#       'text': '{\n  "dept_no": "d001"\n}'}],
#     'structuredContent': {'result': [{'dept_no': 'd001'}]},
#     'isError': False},
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '8de355e8ec506ff6',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 1008.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.311Z',
#    'updatedAt': '2025-11-18T09:18:18.312Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': 'd7b76347737aee84',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 14, 808000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 15, 319000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 511.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '54d03b71de606638',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 14, 290000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 14, 807000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 517.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0},
#   {'id': '4f0f44e9bacc6c26',
#    'traceId': 'bff713e0aaf32710bd3bae79a2143637',
#    'type': 'SPAN',
#    'name': 'a2a.server.events.event_queue.EventQueue.dequeue_event',
#    'startTime': datetime.datetime(2025, 11, 18, 9, 18, 13, 775000, tzinfo=datetime.timezone.utc),
#    'endTime': datetime.datetime(2025, 11, 18, 9, 18, 14, 290000, tzinfo=datetime.timezone.utc),
#    'completionStartTime': None,
#    'model': None,
#    'modelParameters': None,
#    'input': None,
#    'version': None,
#    'metadata': {'attributes': {},
#     'resourceAttributes': {'telemetry.sdk.language': 'python',
#      'telemetry.sdk.name': 'opentelemetry',
#      'telemetry.sdk.version': '1.37.0',
#      'service.name': 'unknown_service'},
#     'scope': {'name': 'a2a-python-sdk', 'version': '1.0.0', 'attributes': {}}},
#    'output': None,
#    'usage': {'input': 0,
#     'output': 0,
#     'total': 0,
#     'unit': <ModelUsageUnit.TOKENS: 'TOKENS'>},
#    'level': <ObservationLevel.DEFAULT: 'DEFAULT'>,
#    'statusMessage': None,
#    'parentObservationId': '654f9356417884dd',
#    'promptId': None,
#    'usageDetails': {},
#    'costDetails': {},
#    'environment': 'default',
#    'promptName': None,
#    'promptVersion': None,
#    'modelId': None,
#    'inputPrice': None,
#    'outputPrice': None,
#    'totalPrice': None,
#    'calculatedInputCost': None,
#    'calculatedOutputCost': None,
#    'calculatedTotalCost': 0.0,
#    'latency': 515.0,
#    'timeToFirstToken': None,
#    'createdAt': '2025-11-18T09:18:18.310Z',
#    'updatedAt': '2025-11-18T09:18:18.311Z',
#    'projectId': 'cmhwzwyvs01fjad07xfmlp94h',
#    'totalTokens': 0,
#    'unit': 'TOKENS',
#    'completionTokens': 0,
#    'promptTokens': 0}],
#  'meta': {'page': 1, 'limit': 50, 'totalItems': 489, 'totalPages': 10}}

# %%
from langfuse import Langfuse
import json
import os
from openai import AzureOpenAI   # or your actual client

langfuse = Langfuse()
trace_id = "5f98442073757da5118c817fc12713d2"

# 1. Fetch the trace
trace = langfuse.api.trace.get(trace_id=trace_id)

# === SMART EXTRACTION OF INPUT & OUTPUT (handles all common formats) ===
raw_input  = trace.input
raw_output = trace.output

# Extract clean question / input
if isinstance(raw_input, dict):
    question = raw_input.get("question") or raw_input.get("messages", [{}])[-1].get("content", "") or str(raw_input)
elif hasattr(raw_input, 'model_dump'):  # Pydantic objects
    question = str(raw_input)
else:
    question = str(raw_input or "")

# Extract clean answer text (handles Gemini, OpenAI, LiteLLM, etc.)
if isinstance(raw_output, dict):
    # Gemini / Vertex AI style
    if "content" in raw_output and "parts" in raw_output["content"]:
        answer = "".join(part.get("text", "") for part in raw_output["content"]["parts"])
    # OpenAI style
    elif "choices" in raw_output:
        answer = raw_output["choices"][0]["message"]["content"]
    else:
        answer = raw_output.get("content", str(raw_output))
else:
    answer = str(raw_output or "No output")

print(f"Question: {question}")
print(f"Answer:   {answer}\n")

# === Rest is the same – Azure LLM judge ===
azure_client = AzureOpenAI(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version="2024-08-01-preview"
)

judge_response = azure_client.chat.completions.create(
    model=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    temperature=0.0,
    response_format={"type": "json_object"},
    messages=[
        {"role": "system", "content": f"""
You are an expert fact-checker. Score factual correctness from 0.0 to 1.0.

Question: {question}
Answer: {answer}

Respond ONLY with JSON: {{"score": 0.94, "explanation": "short reason"}}
        """.strip()}
    ]
)

result = json.loads(judge_response.choices[0].message.content)
score = float(result["score"])

langfuse.create_score(
    trace_id=trace_id,
    name="correctness",
    value=score,
    comment=f"Auto LLM judge: {result.get('explanation', '')}",
    data_type="NUMERIC"
)

print(f"Final LLM Judge Score → {score}")
# Out:
# Question: {'model': 'azure/gpt-4o-mini', 'config': {'system_instruction': '\n        **Role:** Host agent for the agent-to-agent protocol; delegates queries to specialized remote agents with maximum efficiency.\n\n**Core Directives:**\n\n* **Task Delegation:** Use the `send_message` function to assign precise, actionable tasks to remote agents.\n* **Full Context Provision:** If an agent repeatedly asks for user confirmation, it likely lacks conversation history. Include all relevant context in the task to prevent this.\n* **Autonomous Multi-Agent Engagement:** Engage any required agents directly—never seek user permission or preference. If multiple agents are needed, orchestrate them seamlessly.\n* **Intelligent Inter-Agent Collaboration:** Instruct agents to determine if they need data from another agent. **If Agent A says "I need X to proceed" and Agent B can provide X, immediately query Agent B, then resubmit the updated task to Agent A.**\n* **Transparent Output:** Deliver the full, unedited response from the final agent(s) to the user.\n* **Confirmation Handling:** Only relay confirmation requests to the user if not already provided. Never confirm on behalf of the user.\n* **Minimal Context Sharing:** Share only task-relevant context with each agent. Omit irrelevant details.\n* **No Redundancy:** Never ask agents to confirm actions or information.\n* **Tool-Only Responses:** Rely exclusively on tools and agents. If data is missing, request clarification from the user—never assume.\n* **Recency Priority:** Base decisions on the most recent user message.\n* **Active Agent Routing:** Route follow-up queries to the currently active agent using task updates.\n\n**Efficiency Rule:** \n> **Dependency Resolution Loop:**  \n> If Agent A blocks on missing info → Identify Agent B that can supply it → Query B → Feed result back to A → Repeat until A completes or escalates.\n        **Agent Roster:**\n\n        * Available Agents: `{"name": "Get Department Manager", "description": "Gives department manager for a specific department number"}\n{"name": "Get Dept Number", "description": "Gives department number for a specific department name"}`\n        * Currently Active Seller Agent: `Get Department Manager`\n                \n\nYou are an agent. Your internal name is "Routing_agent". The description about you is "This Routing agent orchestrates the decomposition of the user asking for department or manager information.".', 'tools': [{'function_declarations': [{'description': 'Sends a task to remote seller agent.\n\nThis will send a message to the remote agent named agent_name.\n\nArgs:\n    agent_name: The name of the agent to send the task to.\n    task: The comprehensive conversation context summary\n        and goal to be achieved regarding user inquiry and purchase request.\n    tool_context: The tool context this method runs in.\n\nYields:\n    A dictionary of JSON data.\n', 'name': 'send_message', 'parameters': {'properties': {'agent_name': {'type': 'STRING'}, 'task': {'type': 'STRING'}}, 'required': ['agent_name', 'task'], 'type': 'OBJECT'}, 'response': {}}]}], 'labels': {'adk_agent_name': 'Routing_agent'}}, 'contents': [{'parts': [{'text': 'give me the manager name for the department Marketing '}], 'role': 'user'}, {'parts': [{'function_call': {'id': 'call_864soeZGp5hioF6g2A9vB2KD', 'args': {'agent_name': 'Get Dept Number', 'task': "User is requesting the manager's name for the Marketing department. First, find the department number for Marketing."}, 'name': 'send_message'}}], 'role': 'model'}, {'parts': [{'function_response': {'id': 'call_864soeZGp5hioF6g2A9vB2KD', 'name': 'send_message', 'response': {'result': {'artifacts': [{'artifactId': '50710bf0-5d5d-4ece-b711-5c71c85f637f', 'parts': [{'kind': 'text', 'text': "It appears that I mistakenly looked up the department number instead of the manager's name using the department number.\n\nTo find the manager's name for the Marketing department, I will need to switch to a differe ...
# Answer:   Here is the requested information for the Marketing department:
#
# ```json
# {
#     "department_number": "d001",
#     "manager_name": "Alejandro Brender"
# }
# ```
#
# Final LLM Judge Score → 0.94

# %%
import ast
from datetime import datetime, timezone

# %%
# FINAL_WORKING_DEEPEVAL_NOV19_2025.py
import ast
from typing import Dict, List, Any

# DeepEval - latest 2025 API
from deepeval import evaluate
from deepeval.metrics import GEval, FaithfulnessMetric, ToxicityMetric
from deepeval.test_case import LLMTestCase
from deepeval.test_case import LLMTestCaseParams  # ← CRITICAL

# Langfuse
from langfuse import Langfuse

# ===============================================================
# 1. YOUR TRACE (paste full string)
# ===============================================================
# raw_trace = '''{'id': '59b7f43597ffd7104da70b5ecd0b2d4b', ... 'externalId': None}'''
# trace_dict: Dict[str, Any] = ast.literal_eval(raw_trace)

# ===============================================================
# 2. Extract steps
# ===============================================================
def extract_steps(contents: List[Dict]) -> str:
    steps = []
    for part in contents:
        if part.get("role") == "user":
            for p in part["parts"]:
                if "text" in p:
                    steps.append(f"USER: {p['text']}")
                elif "function_response" in p:
                    try:
                        txt = p["function_response"]["response"]["result"]["artifacts"][0]["parts"][0]["text"]
                        steps.append(f"TOOL OUTPUT:\n{txt.strip()}")
                    except:
                        pass
        elif part.get("role") == "model":
            for p in part["parts"]:
                if "function_call" in p:
                    fc = p["function_call"]
                    agent = fc["args"]["agent_name"]
                    task = fc["args"]["task"]
                    steps.append(f"→ CALL: send_message('{agent}')\n    Task: {task}")
                elif "text" in p:
                    steps.append(f"FINAL ANSWER: {p['text']}")
    return "\n\n".join(steps)



# ===============================================================
# 3. Build test case
# ===============================================================
def build_test_case(trace: Dict) -> LLMTestCase:
    contents = trace["input"]["contents"]
    output = trace["output"]["content"]["parts"][0]["text"]
    user_query = next((p["text"] for c in contents if c["role"] == "user" for p in c["parts"] if "text" in p), "")

    full_trace = "=== FULL AGENT ORCHESTRATION TRACE ===\n" + extract_steps(contents)

    return LLMTestCase(
        input=user_query,
        actual_output=output,
        retrieval_context=[full_trace],  # This is how you pass intermediate steps now
    )

# ===============================================================
# 4. METRICS — ONLY THIS WAY WORKS IN NOV 2025
# ===============================================================
def get_metrics():
    return [
        GEval(
            name="Multi-Agent Orchestration Quality",
            criteria="Rate how well the routing agent orchestrated other agents using the trace in retrieval_context.",
            evaluation_steps=[
                "Did it call Get Dept Number first?",
                "Then Get Department Manager with d001?",
                "Only 2 calls total?",
                "No loops, no user involvement?",
                "Final answer is direct and correct?"
            ],
            evaluation_params=[
                LLMTestCaseParams.INPUT,
                LLMTestCaseParams.ACTUAL_OUTPUT,
                LLMTestCaseParams.RETRIEVAL_CONTEXT,
            ],
            model="gpt-4o-mini",
            threshold=0.8
        ),
        GEval(
            name="Efficiency & Minimal Steps",
            criteria="Was the task solved in the absolute minimum number of steps?",
            evaluation_steps=[
                "Exactly 2 agent calls",
                "No redundancy",
                "Perfect dependency resolution"
            ],
            evaluation_params=[
                LLMTestCaseParams.ACTUAL_OUTPUT,
                LLMTestCaseParams.RETRIEVAL_CONTEXT,
            ],
            model="gpt-4o-mini",
            threshold=0.9
        ),
        FaithfulnessMetric(threshold=0.9),
        ToxicityMetric(threshold=0.1),
    ]

# ===============================================================
# 5. Evaluate + Log
# ===============================================================
def evaluate_and_log(trace: Dict):
    test_case = build_test_case(trace)
    metrics = get_metrics()

    print("Running DeepEval evaluation...")
    results = evaluate(test_cases=[test_case], metrics=metrics)  # ← Correct call
    result = results.test_results[0]

    scores = {
        "orchestration_quality": result.score_breakdown["Multi-Agent Orchestration Quality"],
        "efficiency_score": result.score_breakdown["Efficiency & Minimal Steps"],
        "faithfulness": result.score_breakdown["Faithfulness"],
        "toxicity": result.score_breakdown["Toxicity"],
    }
    scores["task_success"] = 1.0 if scores["orchestration_quality"] >= 8.5 and scores["faithfulness"] >= 0.9 else 0.0

    # Optional: Langfuse
    try:
        langfuse = Langfuse()
        lf_trace = langfuse.trace(name="Routing Agent Eval", input=test_case.input, output=test_case.actual_output)
        for k, v in scores.items():
            lf_trace.score(name=k.replace("_", "-"), value=float(v))
    except:
        pass  # Ignore Langfuse warning

    print("\n" + "="*60)
    print("EVALUATION COMPLETE - NOV 19, 2025")
    print("="*60)
    print(f"Orchestration Quality : {scores['orchestration_quality']:.2f}/10")
    print(f"Efficiency            : {scores['efficiency_score']:.2f}/10")
    print(f"Faithfulness          : {scores['faithfulness']:.2f}")
    print(f"Toxicity              : {scores['toxicity']:.2f}")
    print(f"Task Success          : {'YES' if scores['task_success'] else 'NO'}")
    print("="*60)

# ===============================================================
# 6. RUN
# ===============================================================
if __name__ == "__main__":
    evaluate_and_log(x)
# Out:
# Running DeepEval evaluation...
# ✨ You're running DeepEval's latest Multi-Agent Orchestration Quality [GEval] Metric! (using gpt-4o-mini,
# strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Efficiency & Minimal Steps [GEval] Metric! (using gpt-4o-mini, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-4.1, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Toxicity Metric! (using gpt-4.1, strict=False, async_mode=True)...
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# No 'langfuse_public_key' passed to decorated function, but multiple langfuse clients are instantiated in current
# process. Skipping tracing for this function to avoid cross-project leakage.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Multi-Agent Orchestration Quality [GEval] (score: 1.0, threshold: 0.8, strict: False, evaluation model: gpt-4o-mini, reason: The response correctly followed all evaluation steps: it first called 'Get Dept Number' to retrieve the department number for marketing, then called 'Get Department Manager' with the correct department number 'd001'. There were only two calls made, with no loops or user involvement, and the final answer provided was direct and accurate, identifying Alejandro Brender as the manager., error: None)
#   - ✅ Efficiency & Minimal Steps [GEval] (score: 1.0, threshold: 0.9, strict: False, evaluation model: gpt-4o-mini, reason: The response meets all evaluation criteria perfectly. There are exactly 2 agent calls: one to retrieve the department number and another to get the manager's name. There is no redundancy in the calls, as each serves a distinct purpose in the dependency resolution process. The final output correctly identifies the manager of the marketing department based on the retrieved department number, demonstrating perfect dependency resolution., error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.9, strict: False, evaluation model: gpt-4.1, reason: The score is 1.00 because there are no contradictions present. Great job staying true to the retrieval context!, error: None)
#   - ✅ Toxicity (score: 0.0, threshold: 0.1, strict: False, evaluation model: gpt-4.1, reason: The score is 0.00 because the actual output contains no toxic language or harmful content. Great job keeping the response safe and respectful!, error: None)
#
# For test case:
#
#   - input: who is the manager of department marketing?
#   - actual output: The manager of the marketing department (department number d001) is **Alejandro Brender**.
#   - expected output: None
#   - context: None
#   - retrieval context: ['=== FULL AGENT ORCHESTRATION TRACE ===\nUSER: who is the manager of department marketing?\n\n→ CALL: send_message(\'Get Dept Number\')\n    Task: Find the department number for the marketing department in order to identify the manager.\n\nTOOL OUTPUT:\nHere is the information for the marketing department:\n\n```json\n{\n    "department_number": "d001",\n    "department_name": "marketing"\n}\n``` \n\nThis information was retrieved using the `Get_Department_Number` tool.\n\n→ CALL: send_message(\'Get Department Manager\')\n    Task: Retrieve the manager for department number d001, which pertains to the marketing department.\n\nTOOL OUTPUT:\nHere is the information for the marketing department (department number d001):\n\n```json\n{\n    "department_number": "d001",\n    "manager_name": "Alejandro Brender"\n}\n```']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Multi-Agent Orchestration Quality [GEval]: 100.00% pass rate
# Efficiency & Minimal Steps [GEval]: 100.00% pass rate
# Faithfulness: 100.00% pass rate
# Toxicity: 100.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=841494;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 9.94s | token cost: 0.00677625 USD)
# » Test Results (1 total tests):
#    » Pass Rate: 100.0% | Passed: 1 | Failed: 0
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 147
#     143 # ===============================================================
#     144 # 6. RUN
#     145 # ===============================================================
#     146 if __name__ == "__main__":
# --> 147     evaluate_and_log(x)
#
# Cell In[106], line 117, in evaluate_and_log(trace)
#     113 results = evaluate(test_cases=[test_case], metrics=metrics)  # ← Correct call
#     114 result = results.test_results[0]
#     116 scores = {
# --> 117     "orchestration_quality": result.score_breakdown["Multi-Agent Orchestration Quality"],
#     118     "efficiency_score": result.score_breakdown["Efficiency & Minimal Steps"],
#     119     "faithfulness": result.score_breakdown["Faithfulness"],
#     120     "toxicity": result.score_breakdown["Toxicity"],
#     121 }
#     122 scores["task_success"] = 1.0 if scores["orchestration_quality"] >= 8.5 and scores["faithfulness"] >= 0.9 else 0.0
#     124 # Optional: Langfuse
#
# AttributeError: 'TestResult' object has no attribute 'score_breakdown'
